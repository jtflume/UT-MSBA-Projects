# %% [markdown]
# # Lift Calculations

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\conol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import spacy
from nltk.util import ngrams
from collections import Counter
nlp=spacy.load('en_core_web_sm')

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint


# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
#import pyLDAvis.gensim  # don't skip this
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\conol\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %% [markdown]
# ## Import Data

# %%
reviews_df = pd.read_csv('all_reviews.csv')
reviews_df
# Out:
#       Unnamed: 0       company  \
# 0              0          Uber
# 1              1          Uber
# 2              2          Uber
# 3              3          Uber
# 4              4          Uber
# ...          ...           ...
# 9663        5894  VMware, Inc.
# 9664        5895  VMware, Inc.
# 9665        5896  VMware, Inc.
# 9666        5897  VMware, Inc.
# 9667        5898  VMware, Inc.
#
#                                                    pros  \
# 0                Hours, pay, management and environment
# 1                           Work your very own schedule
# 2            Uber stock, good benefits, good experience
# 3                       Decent pay for the work you do.
# 4     Smart people\r\nLots of resources\r\nGreat com...
# ...                                                 ...
# 9663  Was a great place to make good money and be pa...
# 9664      work life balance, good to work with managers
# 9665  The culture and values of this company makes i...
# 9666               Great campus and several onsite gyms
# 9667  Culture and benefits are good. Witht e introdu...
#
#                                                    cons
# 0     I wouldn’t say I had any cons working at this job
# 1                   Sometimes the pay can be unbalanced
# 2              Bad commission structure, limited upside
# 3     The customer service department doesnt take th...
# 4     Fast-moving org - sometimes a little too fast ...
# ...                                                 ...
# 9663  Dell has had too heavy of an influence on the ...
# 9664              easy to get some fantastic experience
# 9665  No cons to share best company to become a part...
# 9666       Hard to find affordable housing near campus.
# 9667  Struggling to change their business model to S...
#
# [9668 rows x 4 columns]

# %% [markdown]
# ## Data Prep

# %%
#Tokenize comment
reviews_df['con_token']=reviews_df['cons'].map(lambda x:nlp(x))
reviews_df['pro_token']=reviews_df['pros'].map(lambda x:nlp(x))

# %%
#frequency count of single words
pro=dict()
for row in range(len(reviews_df)):
    text=reviews_df['pro_token'].iloc[row]
    for word in text:
        if word.is_punct:
            continue
        
        if word.text.lower() in pro:
            pro[word.text.lower()]+=1
        else:
            pro[word.text.lower()]=1

# %%
con=dict()
for row in range(len(reviews_df)):
    text=reviews_df['pro_token'].iloc[row]
    for word in text:
        if word.is_punct:
            continue
        
        if word.text.lower() in con:
            con[word.text.lower()]+=1
        else:
            con[word.text.lower()]=1

# %%
# STEP 2: create dataframe from dictionary
con_count = pd.DataFrame.from_dict(con, orient = 'index')
con_count.columns=['count']
con_count=con_count.sort_values(by='count',ascending=False)

# STEP 2: create dataframe from dictionary
pro_count = pd.DataFrame.from_dict(con, orient = 'index')
pro_count.columns=['count']
pro_count=pro_count.sort_values(by='count',ascending=False)

# %%
con_count.to_csv('con_count.csv')
pro_count.to_csv('pro_count.csv')

# %% [markdown]
# ## Lift

# %%
diversitypro = ('diveristy', 'inclusive','diverse')
environmentpro = ('room','space','location','food','environment','office', 'perks', 'technoolgy', 'food', 'tech','environment')
culturepro = ('positive','helpful','family','atmosphere','community','coworkers','company', 'people', 'culture', 'team','fun','care','friendly','colleagues','supportive','support','remote','values','cares','mission','collaborative','competitive','staff','caring')
worklifepro = ('vacation','life','balance','flexible','hours','flexibility','schedule','pto')
paypro = ('money','401k','insurance','pay', 'salary','compensation','stock','benefits','bonuses','options')
careergrowthpro = ('impact','opportunity','growth','opportunity','career','grow','growing','research')
leadershippro = ('vision','leaders','leadership','management','managers','ceo','manager')
personaldevpro = ('skills','driven','training','resources','success','learning','projects','experience','learn','challenging','resources','development')

# %%
def replace(comment):
    new_comment = []
    for word in comment:
        if word.is_punct:
            continue
        elif word.is_stop:
            continue
        elif word.text.lower() in diversitypro:
            word='diversity'
            new_comment.append(word)
        elif word.text.lower() in environmentpro:
            word='environment'
            new_comment.append(word)
        elif word.text.lower() in culturepro:
            word='culture'
            new_comment.append(word)
        elif word.text.lower() in worklifepro:
            word='worklife'
            new_comment.append(word)
        elif word.text.lower() in paypro:
            word='pay'
            new_comment.append(word)
        elif word.text.lower() in careergrowthpro:
            word='growth'
            new_comment.append(word)
        elif word.text.lower() in leadershippro:
            word='leadership'
            new_comment.append(word)
        elif word.text.lower() in personaldevpro:
            word='personaldevelopment'
            new_comment.append(word)
        else: 
            word = word.text.lower()
            new_comment.append(word)
        
    return(' '.join(new_comment))

reviews_df['pro_replace']=reviews_df['pro_token'].map(replace)
reviews_df['con_replace']=reviews_df['con_token'].map(replace)

# %%
featuresnames = ('diversity','environment','culture','worklife','pay','growth','leadership','personaldevelopment')

# %%
firm = pd.DataFrame(reviews_df['company'].value_counts())
firmname = firm.index

# %%
#Tokenize comment
reviews_df['con_replace_token']=reviews_df['con_replace'].map(lambda x:nlp(x))
reviews_df['pro_replace_token']=reviews_df['pro_replace'].map(lambda x:nlp(x))

# %%
pro_attributes = []


for row in range(len(reviews_df)):
    text=reviews_df['pro_replace_token'].iloc[row]
    attributelist = list()
    for word in text:
        if word.is_punct:
            continue
        if word.text in featuresnames:
            attributelist.append(word.text)
    pro_attributes.append(attributelist)
pro_attributes
# Out:
# [['worklife', 'pay', 'leadership', 'environment'],
#  ['worklife'],
#  ['pay', 'pay', 'personaldevelopment'],
#  ['pay'],
#  ['culture', 'personaldevelopment', 'pay', 'environment', 'culture'],
#  ['pay'],
#  ['culture',
#   'growth',
#   'growth',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'pay',
#   'environment'],
#  ['pay', 'culture'],
#  [],
#  ['worklife', 'pay'],
#  ['pay'],
#  ['worklife', 'worklife', 'worklife', 'worklife'],
#  ['culture', 'culture'],
#  ['pay'],
#  [],
#  ['culture', 'environment'],
#  ['worklife'],
#  ['worklife', 'worklife', 'pay'],
#  ['growth'],
#  ['worklife'],
#  ['pay', 'growth', 'culture'],
#  ['pay'],
#  ['pay'],
#  [],
#  ['culture', 'pay', 'culture'],
#  ['personaldevelopment', 'pay', 'culture', 'growth', 'culture'],
#  ['culture', 'pay'],
#  ['pay'],
#  ['worklife',
#   'worklife',
#   'worklife',
#   'worklife',
#   'pay',
#   'pay',
#   'pay',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment'],
#  ['pay', 'worklife', 'culture'],
#  ['worklife', 'worklife'],
#  ['culture', 'growth', 'culture'],
#  ['pay', 'pay'],
#  [],
#  ['worklife', 'pay'],
#  ['culture'],
#  ['culture', 'worklife', 'worklife'],
#  ['leadership'],
#  ['culture', 'worklife'],
#  ['growth',
#   'growth',
#   'culture',
#   'growth',
#   'culture',
#   'environment',
#   'culture',
#   'growth'],
#  ['culture', 'leadership', 'personaldevelopment'],
#  ['worklife', 'worklife'],
#  ['worklife', 'worklife', 'culture'],
#  ['worklife', 'culture'],
#  ['pay'],
#  ['worklife'],
#  ['culture', 'environment'],
#  [],
#  ['worklife', 'culture'],
#  ['environment', 'environment', 'environment', 'diversity'],
#  ['pay', 'culture'],
#  ['worklife', 'culture'],
#  ['worklife'],
#  ['worklife'],
#  ['personaldevelopment', 'growth', 'culture'],
#  [],
#  ['culture'],
#  [],
#  [],
#  ['culture'],
#  ['worklife', 'worklife'],
#  ['growth', 'personaldevelopment', 'culture'],
#  [],
#  [],
#  [],
#  ['worklife', 'culture'],
#  ['pay', 'environment'],
#  [],
#  ['pay'],
#  ['pay', 'pay', 'worklife', 'worklife'],
#  ['worklife', 'pay'],
#  ['worklife', 'pay'],
#  ['worklife', 'environment', 'pay'],
#  ['worklife', 'worklife'],
#  ['worklife', 'leadership', 'culture', 'personaldevelopment'],
#  ['worklife', 'worklife'],
#  ['worklife', 'pay'],
#  ['culture'],
#  [],
#  [],
#  ['worklife', 'culture'],
#  ['environment'],
#  [],
#  ['worklife', 'worklife'],
#  [],
#  ['pay', 'pay'],
#  ['worklife', 'worklife'],
#  [],
#  ['worklife', 'worklife'],
#  [],
#  ['culture'],
#  ['worklife'],
#  ['worklife', 'worklife', 'environment', 'pay'],
#  ['culture', 'leadership', 'pay', 'culture', 'pay', 'culture'],
#  ['worklife', 'worklife', 'leadership'],
#  ['pay'],
#  [],
#  [],
#  ['worklife', 'worklife', 'pay'],
#  [],
#  ['worklife', 'worklife'],
#  ['pay', 'culture', 'growth', 'pay', 'personaldevelopment'],
#  ['worklife', 'worklife', 'culture', 'pay'],
#  ['worklife'],
#  ['worklife',
#   'worklife',
#   'pay',
#   'growth',
#   'growth',
#   'personaldevelopment',
#   'culture'],
#  ['growth', 'personaldevelopment', 'personaldevelopment', 'culture'],
#  ['diversity',
#   'growth',
#   'growth',
#   'growth',
#   'worklife',
#   'worklife',
#   'worklife'],
#  ['worklife',
#   'worklife',
#   'leadership',
#   'culture',
#   'growth',
#   'personaldevelopment',
#   'culture',
#   'diversity',
#   'culture',
#   'pay'],
#  ['worklife',
#   'worklife',
#   'culture',
#   'culture',
#   'pay',
#   'culture',
#   'leadership',
#   'culture'],
#  ['worklife', 'worklife', 'worklife', 'leadership'],
#  ['culture', 'culture'],
#  ['personaldevelopment',
#   'growth',
#   'growth',
#   'culture',
#   'culture',
#   'worklife',
#   'culture'],
#  ['culture', 'culture', 'growth', 'growth', 'personaldevelopment'],
#  ['pay', 'pay'],
#  ['worklife', 'worklife'],
#  ['pay', 'environment', 'leadership'],
#  [],
#  ['personaldevelopment'],
#  ['personaldevelopment', 'personaldevelopment', 'worklife'],
#  ['pay', 'pay', 'worklife', 'worklife', 'pay', 'pay'],
#  ['personaldevelopment'],
#  ['personaldevelopment', 'worklife', 'worklife', 'worklife', 'worklife'],
#  ['personaldevelopment', 'personaldevelopment', 'worklife', 'worklife'],
#  ['culture',
#   'culture',
#   'culture',
#   'worklife',
#   'worklife',
#   'leadership',
#   'worklife'],
#  ['personaldevelopment', 'worklife', 'worklife'],
#  ['culture'],
#  [],
#  [],
#  ['worklife', 'worklife', 'pay'],
#  ['pay', 'leadership', 'culture'],
#  ['personaldevelopment'],
#  ['culture', 'worklife', 'worklife'],
#  ['culture', 'culture', 'culture'],
#  ['personaldevelopment'],
#  ['worklife', 'worklife', 'pay'],
#  ['leadership', 'culture'],
#  ['growth'],
#  ['worklife', 'pay'],
#  ['pay', 'worklife', 'worklife'],
#  [],
#  ['culture', 'growth', 'worklife', 'worklife'],
#  ['diversity', 'environment', 'culture'],
#  ['culture', 'personaldevelopment'],
#  ['worklife', 'culture'],
#  ['personaldevelopment', 'environment'],
#  ['culture', 'growth'],
#  [],
#  ['leadership'],
#  ['growth', 'worklife', 'personaldevelopment'],
#  ['culture', 'culture', 'worklife'],
#  ['personaldevelopment'],
#  ['environment'],
#  ['pay', 'worklife', 'worklife'],
#  [],
#  ['culture'],
#  ['personaldevelopment', 'growth'],
#  ['personaldevelopment'],
#  ['growth'],
#  ['culture', 'culture'],
#  ['worklife', 'worklife', 'personaldevelopment', 'growth'],
#  ['worklife', 'worklife', 'pay'],
#  ['growth'],
#  ['culture'],
#  ['culture', 'growth'],
#  ['environment', 'pay'],
#  ['culture', 'growth', 'personaldevelopment'],
#  [],
#  ['leadership', 'personaldevelopment'],
#  ['personaldevelopment'],
#  ['culture'],
#  ['culture', 'pay', 'culture'],
#  ['pay', 'pay'],
#  ['worklife', 'worklife', 'pay'],
#  [],
#  ['culture', 'culture', 'culture'],
#  ['culture', 'culture'],
#  ['pay', 'personaldevelopment', 'culture', 'growth'],
#  ['culture'],
#  ['growth'],
#  ['culture', 'pay'],
#  ['culture'],
#  [],
#  ['pay', 'worklife', 'pay', 'environment'],
#  ['environment', 'pay', 'pay'],
#  ['pay', 'pay'],
#  ['culture'],
#  [],
#  ['culture', 'culture', 'worklife', 'culture'],
#  [],
#  ['culture', 'personaldevelopment'],
#  ['culture', 'growth', 'culture'],
#  ['pay', 'growth', 'growth', 'worklife', 'worklife'],
#  ['worklife', 'culture', 'culture', 'culture'],
#  ['environment', 'culture'],
#  ['culture'],
#  ['culture'],
#  ['culture'],
#  ['culture'],
#  ['culture', 'culture'],
#  ['worklife', 'worklife', 'culture', 'pay', 'culture', 'diversity'],
#  [],
#  ['culture',
#   'growth',
#   'growth',
#   'culture',
#   'pay',
#   'pay',
#   'environment',
#   'environment'],
#  ['culture', 'growth', 'culture', 'personaldevelopment', 'diversity'],
#  ['personaldevelopment',
#   'personaldevelopment',
#   'pay',
#   'personaldevelopment',
#   'culture'],
#  ['personaldevelopment', 'culture', 'environment', 'culture', 'culture'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'growth'],
#  ['personaldevelopment',
#   'leadership',
#   'culture',
#   'growth',
#   'growth',
#   'personaldevelopment',
#   'leadership',
#   'culture',
#   'culture'],
#  ['culture', 'culture', 'personaldevelopment'],
#  ['culture', 'culture', 'leadership'],
#  ['culture', 'culture', 'culture'],
#  ['pay'],
#  ['pay', 'pay'],
#  ['pay'],
#  ['culture', 'culture', 'worklife', 'worklife'],
#  ['environment'],
#  ['leadership', 'culture'],
#  [],
#  [],
#  ['environment', 'culture', 'pay', 'worklife', 'worklife'],
#  ['pay'],
#  ['growth', 'leadership'],
#  ['pay', 'pay'],
#  ['worklife', 'worklife', 'environment', 'pay'],
#  ['pay'],
#  ['pay'],
#  ['pay', 'culture'],
#  ['worklife', 'culture', 'worklife', 'worklife'],
#  ['worklife', 'worklife', 'pay'],
#  ['culture', 'pay'],
#  ['pay', 'growth', 'growth', 'pay', 'pay'],
#  ['pay'],
#  [],
#  ['pay', 'pay'],
#  ['leadership'],
#  ['pay', 'culture'],
#  ['personaldevelopment', 'environment'],
#  ['leadership', 'worklife', 'worklife'],
#  ['pay'],
#  ['growth', 'pay', 'pay'],
#  ['culture'],
#  ['culture'],
#  ['culture'],
#  ['personaldevelopment'],
#  ['pay', 'pay'],
#  ['worklife', 'worklife', 'worklife'],
#  ['culture', 'pay'],
#  ['leadership', 'culture'],
#  ['pay', 'pay', 'culture', 'environment'],
#  ['pay'],
#  ['culture'],
#  [],
#  ['pay', 'pay', 'pay', 'pay'],
#  ['culture', 'pay', 'environment', 'culture', 'culture'],
#  ['culture'],
#  ['environment', 'culture'],
#  ['culture', 'pay', 'pay'],
#  ['environment'],
#  ['leadership'],
#  ['worklife'],
#  ['culture', 'pay', 'pay', 'worklife', 'worklife', 'worklife'],
#  ['culture'],
#  ['pay'],
#  ['culture'],
#  [],
#  ['worklife', 'pay', 'worklife'],
#  [],
#  [],
#  ['pay', 'pay'],
#  ['worklife', 'worklife'],
#  ['worklife', 'worklife', 'pay', 'pay'],
#  [],
#  ['leadership', 'growth', 'worklife', 'worklife'],
#  ['worklife'],
#  ['worklife'],
#  [],
#  [],
#  ['worklife'],
#  ['pay', 'worklife'],
#  ['leadership', 'culture', 'pay', 'culture'],
#  [],
#  [],
#  [],
#  ['worklife', 'worklife'],
#  [],
#  [],
#  ['worklife', 'pay', 'growth', 'growth'],
#  ['pay', 'culture', 'environment'],
#  ['culture', 'culture'],
#  ['pay'],
#  ['culture'],
#  ['culture', 'worklife'],
#  ['culture', 'culture', 'personaldevelopment', 'personaldevelopment'],
#  ['culture', 'pay'],
#  ['personaldevelopment', 'leadership'],
#  ['pay'],
#  ['worklife', 'pay'],
#  [],
#  ['culture'],
#  ['worklife', 'growth'],
#  ['culture', 'environment'],
#  ['culture', 'pay'],
#  ['culture', 'culture'],
#  ['worklife', 'culture'],
#  ['environment', 'environment', 'environment'],
#  ['pay'],
#  [],
#  [],
#  ['worklife', 'worklife', 'culture', 'environment'],
#  ['worklife', 'worklife', 'pay', 'pay', 'culture', 'culture'],
#  [],
#  ['culture', 'environment', 'pay', 'growth', 'worklife', 'worklife'],
#  ['leadership', 'culture', 'culture', 'leadership'],
#  ['culture'],
#  ['culture'],
#  ['culture'],
#  [],
#  ['culture'],
#  ['culture', 'culture', 'culture', 'worklife', 'culture'],
#  ['diversity', 'growth', 'environment', 'leadership', 'culture'],
#  ['personaldevelopment', 'growth'],
#  ['worklife', 'leadership'],
#  ['environment', 'personaldevelopment', 'culture', 'growth', 'growth'],
#  ['culture', 'personaldevelopment', 'growth', 'culture'],
#  ['culture', 'environment'],
#  [],
#  [],
#  ['culture', 'pay', 'environment', 'culture'],
#  [],
#  ['environment'],
#  [],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment'],
#  ['culture', 'culture'],
#  ['culture'],
#  ['culture', 'culture'],
#  [],
#  ['culture', 'culture'],
#  ['culture'],
#  ['pay',
#   'personaldevelopment',
#   'personaldevelopment',
#   'leadership',
#   'leadership',
#   'leadership',
#   'worklife'],
#  ['growth'],
#  ['culture'],
#  ['environment', 'culture'],
#  ['pay', 'pay', 'pay', 'culture', 'culture', 'environment'],
#  ['culture'],
#  ['culture', 'culture', 'culture', 'culture'],
#  ['personaldevelopment',
#   'worklife',
#   'worklife',
#   'growth',
#   'personaldevelopment',
#   'pay',
#   'culture',
#   'growth'],
#  ['culture', 'culture', 'leadership'],
#  ['culture', 'growth'],
#  ['culture', 'culture'],
#  ['culture'],
#  [],
#  ['pay', 'pay', 'culture', 'environment'],
#  ['culture', 'environment'],
#  ['culture', 'leadership', 'culture', 'leadership'],
#  ['culture', 'environment'],
#  ['culture', 'environment'],
#  [],
#  ['culture', 'pay'],
#  ['worklife', 'environment'],
#  ['culture', 'culture', 'environment'],
#  ['culture'],
#  [],
#  ['environment'],
#  ['culture', 'pay', 'personaldevelopment'],
#  ['environment', 'culture', 'culture'],
#  ['worklife', 'culture'],
#  [],
#  ['culture', 'culture'],
#  ['culture', 'personaldevelopment'],
#  [],
#  ['pay', 'culture'],
#  [],
#  ['culture', 'pay'],
#  ['pay'],
#  ['culture'],
#  ['culture'],
#  [],
#  ['culture', 'environment'],
#  ['pay'],
#  ['environment'],
#  ['pay', 'pay'],
#  ['personaldevelopment', 'culture', 'environment'],
#  ['personaldevelopment', 'culture', 'culture'],
#  ['culture', 'culture'],
#  ['culture', 'environment', 'worklife', 'worklife'],
#  ['growth', 'personaldevelopment'],
#  ['culture'],
#  ['environment', 'culture', 'leadership', 'personaldevelopment'],
#  ['culture',
#   'personaldevelopment',
#   'growth',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'environment'],
#  ['culture', 'personaldevelopment'],
#  ['worklife', 'culture'],
#  ['leadership',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'pay',
#   'pay',
#   'culture'],
#  ['worklife', 'personaldevelopment', 'leadership'],
#  ['personaldevelopment',
#   'culture',
#   'pay',
#   'worklife',
#   'worklife',
#   'personaldevelopment',
#   'personaldevelopment',
#   'personaldevelopment',
#   'environment',
#   'personaldevelopment',
#   'culture',
#   'worklife',
#   'culture',
#   'culture'],
#  ['pay', 'personaldevelopment'],
#  [],
#  ['pay', 'environment', 'environment'],
#  ['pay'],
#  ['culture',
#   'culture',
#   'pay',
#   'pay',
#   'culture',
#   'culture',
#   'culture',
#   'leadership',
#   'culture',
#   'culture',
#   'growth',
#   'culture'],
#  ['pay', 'culture', 'culture', 'environment'],
#  ['culture', 'culture', 'culture', 'culture', 'culture'],
#  ['personaldevelopment', 'pay', 'pay', 'culture', 'culture'],
#  ['culture', 'culture', 'environment'],
#  ['culture', 'culture'],
#  ['environment'],
#  ['pay'],
#  ['culture', 'personaldevelopment', 'culture', 'culture'],
#  ['worklife',
#   'personaldevelopment',
#   'culture',
#   'pay',
#   'growth',
#   'environment',
#   'leadership',
#   'culture',
#   'diversity'],
#  ['pay'],
#  [],
#  ['pay'],
#  ['culture'],
#  [],
#  ['pay'],
#  ['personaldevelopment', 'culture', 'culture'],
#  ['culture'],
#  ['culture', 'pay', 'culture', 'culture'],
#  ['culture'],
#  [],
#  [],
#  [],
#  ['culture'],
#  ['leadership', 'pay', 'pay'],
#  [],
#  ['leadership', 'pay', 'growth'],
#  ['culture',
#   'leadership',
#   'culture',
#   'personaldevelopment',
#   'leadership',
#   'culture',
#   'culture'],
#  ['culture', 'growth'],
#  ['culture'],
#  [],
#  [],
#  ['culture', 'culture'],
#  ['pay',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'leadership'],
#  ['worklife', 'worklife', 'leadership'],
#  ['pay', 'worklife'],
#  ['leadership',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'pay',
#   'pay',
#   'culture'],
#  ['pay'],
#  [],
#  ['worklife', 'worklife', 'pay', 'personaldevelopment', 'personaldevelopment'],
#  ['environment'],
#  ['leadership', 'worklife', 'personaldevelopment'],
#  ['environment'],
#  ['culture'],
#  ['worklife', 'worklife', 'culture', 'environment', 'culture', 'leadership'],
#  ['culture', 'culture', 'culture', 'culture'],
#  ['culture', 'culture', 'growth', 'pay'],
#  ['culture'],
#  [],
#  ['growth', 'leadership'],
#  [],
#  ['worklife', 'culture'],
#  ['leadership'],
#  ['culture', 'personaldevelopment'],
#  ['personaldevelopment', 'environment'],
#  ['growth', 'diversity'],
#  ['personaldevelopment', 'personaldevelopment', 'personaldevelopment'],
#  [],
#  ['culture', 'culture', 'leadership'],
#  [],
#  ['culture'],
#  [],
#  ['worklife', 'worklife'],
#  ['pay', 'environment', 'leadership'],
#  ['pay', 'growth'],
#  ['culture'],
#  ['environment', 'pay'],
#  ['culture', 'environment'],
#  ['leadership', 'culture'],
#  ['culture'],
#  ['diversity', 'leadership', 'growth'],
#  ['personaldevelopment', 'personaldevelopment'],
#  ['pay', 'pay'],
#  ['pay', 'pay'],
#  ['culture', 'culture'],
#  ['culture'],
#  ['culture', 'worklife', 'worklife', 'leadership'],
#  [],
#  ['pay'],
#  ['leadership', 'leadership', 'worklife', 'culture', 'culture'],
#  ['culture', 'culture', 'pay'],
#  ['environment'],
#  ['pay'],
#  ['environment',
#   'pay',
#   'culture',
#   'culture',
#   'growth',
#   'culture',
#   'culture',
#   'environment',
#   'growth'],
#  ['culture', 'worklife'],
#  ['environment', 'culture'],
#  ['environment', 'personaldevelopment', 'culture'],
#  ['culture'],
#  ['worklife'],
#  [],
#  ['culture'],
#  ['growth', 'growth'],
#  ['worklife', 'worklife', 'culture', 'culture', 'personaldevelopment'],
#  ['culture', 'culture', 'environment'],
#  ['diversity', 'worklife'],
#  ['worklife'],
#  ['culture', 'pay', 'pay', 'personaldevelopment', 'worklife'],
#  ['environment', 'growth', 'pay', 'environment'],
#  ['environment', 'culture', 'culture', 'worklife', 'worklife'],
#  ['culture'],
#  ['leadership', 'culture', 'culture'],
#  ['environment', 'pay', 'pay'],
#  ['leadership', 'worklife', 'environment'],
#  ['culture', 'pay', 'leadership'],
#  ['culture', 'culture', 'culture', 'pay'],
#  ['culture'],
#  ['worklife', 'worklife'],
#  ['culture', 'culture', 'pay', 'worklife', 'worklife', 'worklife'],
#  ['pay', 'pay', 'leadership', 'worklife', 'worklife'],
#  ['worklife', 'worklife', 'diversity', 'culture'],
#  ['culture', 'environment'],
#  ['worklife', 'worklife', 'pay', 'culture'],
#  ['pay', 'culture'],
#  ['culture', 'growth', 'growth', 'culture', 'culture', 'culture'],
#  ['leadership', 'culture'],
#  ['worklife', 'culture', 'culture', 'culture'],
#  ['worklife', 'leadership'],
#  ['worklife', 'worklife', 'worklife', 'culture', 'pay'],
#  ['pay', 'pay', 'culture', 'culture'],
#  ['growth', 'growth'],
#  ['culture', 'pay'],
#  [],
#  ['culture', 'personaldevelopment', 'culture'],
#  ['personaldevelopment'],
#  ['culture'],
#  ['culture', 'culture'],
#  ['culture', 'culture'],
#  ['environment', 'culture'],
#  ['pay', 'worklife', 'environment'],
#  ['pay', 'growth', 'personaldevelopment'],
#  ['pay'],
#  ['culture', 'growth', 'environment'],
#  ['culture', 'culture', 'diversity'],
#  ['culture', 'pay'],
#  ['pay', 'pay'],
#  ['culture'],
#  ['culture', 'culture', 'environment'],
#  ['pay', 'culture'],
#  ['culture', 'culture'],
#  ['culture'],
#  ['culture'],
#  ['culture', 'worklife', 'worklife', 'pay'],
#  [],
#  ['environment', 'pay', 'pay'],
#  ['culture', 'worklife', 'worklife'],
#  ['environment', 'culture', 'leadership', 'culture'],
#  ['personaldevelopment'],
#  ['culture', 'pay', 'environment', 'culture', 'leadership'],
#  ['pay'],
#  ['culture', 'environment', 'environment', 'diversity'],
#  ['worklife', 'worklife'],
#  ['pay',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'environment',
#   'personaldevelopment',
#   'culture',
#   'worklife',
#   'diversity'],
#  ['worklife', 'worklife', 'culture'],
#  ['pay', 'culture'],
#  ['worklife', 'worklife'],
#  ['culture'],
#  ['culture', 'culture', 'worklife', 'worklife'],
#  ['worklife', 'worklife', 'environment'],
#  ['culture', 'leadership'],
#  ['worklife', 'worklife', 'culture'],
#  ['worklife', 'worklife', 'culture', 'culture'],
#  ['worklife', 'worklife', 'leadership', 'pay'],
#  ['culture', 'worklife', 'worklife', 'environment', 'culture', 'pay'],
#  ['worklife', 'environment'],
#  ['worklife', 'worklife', 'culture', 'culture'],
#  ['culture'],
#  [],
#  ['culture', 'environment'],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['pay', 'leadership', 'culture'],
#  ['culture', 'leadership', 'personaldevelopment', 'worklife', 'worklife'],
#  ['worklife', 'worklife', 'environment', 'pay', 'culture', 'environment'],
#  ['pay',
#   'personaldevelopment',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture'],
#  ['pay', 'worklife', 'worklife'],
#  ['worklife', 'worklife', 'culture'],
#  ['worklife', 'worklife', 'pay'],
#  ['culture', 'leadership', 'pay', 'pay'],
#  ['culture',
#   'culture',
#   'worklife',
#   'worklife',
#   'personaldevelopment',
#   'growth',
#   'pay',
#   'pay',
#   'growth',
#   'culture'],
#  ['pay', 'pay', 'culture'],
#  ['culture',
#   'personaldevelopment',
#   'leadership',
#   'growth',
#   'diversity',
#   'culture',
#   'culture'],
#  ['growth', 'culture', 'culture'],
#  ['culture', 'personaldevelopment', 'personaldevelopment'],
#  ['culture', 'culture', 'leadership', 'culture', 'pay'],
#  ['growth', 'personaldevelopment', 'leadership', 'pay', 'pay'],
#  ['pay', 'culture', 'culture'],
#  ['culture', 'culture', 'pay', 'growth'],
#  ['culture'],
#  ['culture', 'worklife', 'worklife'],
#  ['worklife', 'worklife'],
#  ['worklife', 'worklife', 'culture', 'leadership', 'culture'],
#  ['culture'],
#  ['culture', 'growth', 'personaldevelopment'],
#  ['environment',
#   'environment',
#   'environment',
#   'pay',
#   'environment',
#   'culture',
#   'pay',
#   'pay',
#   'culture',
#   'growth',
#   'growth',
#   'growth'],
#  ['personaldevelopment',
#   'culture',
#   'environment',
#   'culture',
#   'culture',
#   'pay',
#   'diversity',
#   'personaldevelopment',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'environment',
#   'culture',
#   'culture',
#   'worklife',
#   'worklife',
#   'worklife',
#   'worklife',
#   'worklife',
#   'culture',
#   'worklife',
#   'culture',
#   'culture',
#   'culture',
#   'leadership',
#   'environment',
#   'culture'],
#  ['culture'],
#  ['culture'],
#  ['pay', 'pay', 'pay'],
#  [],
#  ['environment', 'growth'],
#  ['worklife', 'worklife'],
#  ['pay', 'pay'],
#  ['worklife', 'environment', 'culture'],
#  ['environment'],
#  ['environment'],
#  [],
#  ['environment', 'growth'],
#  ['pay', 'culture'],
#  ['personaldevelopment'],
#  [],
#  ['culture', 'culture', 'environment'],
#  ['pay'],
#  ['environment'],
#  ['worklife', 'worklife', 'pay'],
#  ['growth', 'personaldevelopment', 'growth'],
#  ['worklife'],
#  [],
#  [],
#  ['pay'],
#  ['worklife', 'worklife'],
#  ['pay', 'growth', 'growth'],
#  [],
#  ['culture', 'culture'],
#  ['culture'],
#  ['culture', 'personaldevelopment'],
#  ['culture', 'culture', 'pay', 'culture', 'pay'],
#  ['pay'],
#  ['worklife', 'worklife'],
#  [],
#  ['worklife', 'worklife'],
#  [],
#  ['pay', 'worklife', 'worklife'],
#  ['culture'],
#  [],
#  ['culture', 'growth'],
#  [],
#  ['pay', 'worklife', 'worklife', 'culture'],
#  [],
#  ['environment'],
#  ['culture'],
#  ['culture'],
#  [],
#  ['worklife', 'worklife', 'culture'],
#  ['culture'],
#  ['worklife', 'worklife', 'pay'],
#  ['culture', 'culture', 'personaldevelopment'],
#  ['culture', 'culture', 'culture'],
#  ['culture'],
#  [],
#  ['culture', 'personaldevelopment'],
#  ['culture', 'culture'],
#  ['culture', 'environment', 'culture'],
#  [],
#  ['pay', 'growth', 'growth', 'growth'],
#  [],
#  ['pay', 'environment', 'environment'],
#  ['worklife', 'leadership'],
#  ['growth'],
#  ['environment'],
#  ['culture', 'culture'],
#  ['pay', 'culture'],
#  ['culture'],
#  ['pay', 'worklife', 'worklife'],
#  ['pay', 'culture'],
#  ['culture', 'personaldevelopment', 'environment'],
#  ['culture', 'pay'],
#  ['culture', 'environment', 'environment'],
#  [],
#  ['culture', 'pay', 'culture'],
#  ['pay'],
#  ['pay'],
#  ['culture', 'pay', 'culture'],
#  [],
#  ['pay', 'environment'],
#  ['culture', 'pay', 'worklife', 'worklife', 'environment', 'worklife'],
#  [],
#  ['culture'],
#  ['culture', 'personaldevelopment'],
#  ['culture', 'personaldevelopment', 'personaldevelopment'],
#  ['pay', 'pay', 'culture', 'culture'],
#  [],
#  ['environment'],
#  ['culture', 'culture', 'pay'],
#  ['pay', 'worklife', 'culture'],
#  [],
#  ['culture', 'culture', 'pay'],
#  ['culture', 'leadership'],
#  ['growth', 'leadership', 'pay', 'culture', 'culture', 'culture'],
#  ['culture', 'culture', 'culture'],
#  ['culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'personaldevelopment',
#   'growth',
#   'culture',
#   'leadership',
#   'culture',
#   'leadership'],
#  ['culture', 'culture', 'culture', 'personaldevelopment', 'growth'],
#  ['culture', 'culture', 'culture', 'culture', 'pay', 'pay'],
#  ['growth',
#   'culture',
#   'leadership',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'culture'],
#  ['pay', 'pay', 'culture', 'culture', 'environment', 'growth', 'growth'],
#  ['leadership', 'leadership', 'culture'],
#  ['leadership', 'culture', 'culture', 'culture', 'culture', 'diversity'],
#  ['culture', 'culture', 'culture', 'culture'],
#  ['diversity', 'culture'],
#  ['culture', 'diversity'],
#  ['growth', 'leadership', 'personaldevelopment'],
#  ['environment', 'pay', 'environment', 'culture', 'growth', 'growth'],
#  ['culture', 'growth', 'leadership', 'culture', 'culture'],
#  ['culture', 'culture', 'culture'],
#  ['culture', 'culture', 'culture', 'environment', 'leadership'],
#  ['growth',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'leadership',
#   'environment',
#   'environment',
#   'culture'],
#  ['culture',
#   'culture',
#   'culture',
#   'leadership',
#   'culture',
#   'culture',
#   'culture'],
#  ['environment', 'growth', 'culture'],
#  ['worklife', 'worklife', 'culture', 'culture'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'growth',
#   'growth',
#   'culture'],
#  ['growth', 'pay', 'culture', 'culture', 'culture'],
#  ['culture',
#   'culture',
#   'culture',
#   'growth',
#   'personaldevelopment',
#   'leadership',
#   'culture'],
#  ['personaldevelopment',
#   'leadership',
#   'personaldevelopment',
#   'culture',
#   'culture'],
#  ['pay', 'pay', 'pay', 'growth', 'growth', 'personaldevelopment'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'personaldevelopment',
#   'leadership',
#   'diversity',
#   'leadership',
#   'growth',
#   'culture'],
#  ['culture', 'leadership', 'leadership', 'pay'],
#  ['culture', 'culture'],
#  ['culture', 'culture', 'culture', 'culture', 'environment', 'worklife'],
#  ['culture', 'culture', 'culture', 'pay', 'diversity'],
#  ['environment', 'leadership', 'culture', 'personaldevelopment'],
#  ['pay', 'worklife', 'culture', 'culture', 'culture'],
#  ['personaldevelopment', 'leadership', 'culture', 'pay'],
#  ['growth', 'leadership', 'worklife', 'diversity'],
#  ['leadership'],
#  ['leadership',
#   'leadership',
#   'culture',
#   'culture',
#   'growth',
#   'growth',
#   'culture'],
#  ['environment', 'culture', 'culture', 'culture', 'growth'],
#  ['culture',
#   'diversity',
#   'culture',
#   'pay',
#   'diversity',
#   'pay',
#   'pay',
#   'growth',
#   'pay',
#   'culture',
#   'pay'],
#  ['worklife'],
#  ['culture', 'personaldevelopment', 'culture', 'environment'],
#  ['leadership',
#   'culture',
#   'growth',
#   'personaldevelopment',
#   'culture',
#   'pay',
#   'leadership'],
#  ['culture', 'culture', 'culture', 'personaldevelopment', 'growth'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'growth',
#   'growth',
#   'growth',
#   'growth',
#   'growth',
#   'growth',
#   'culture',
#   'culture'],
#  ['culture', 'culture', 'personaldevelopment', 'culture', 'culture'],
#  ['culture', 'growth', 'growth', 'growth', 'culture', 'culture'],
#  ['culture', 'personaldevelopment', 'pay', 'leadership', 'growth'],
#  ['personaldevelopment',
#   'leadership',
#   'culture',
#   'leadership',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'growth',
#   'culture',
#   'growth'],
#  ['growth'],
#  ['culture', 'growth'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'growth',
#   'culture',
#   'culture'],
#  ['culture', 'culture', 'personaldevelopment', 'culture'],
#  ['environment', 'culture', 'environment'],
#  ['leadership', 'culture', 'worklife', 'worklife'],
#  ['culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'leadership',
#   'culture'],
#  ['culture',
#   'culture',
#   'environment',
#   'worklife',
#   'worklife',
#   'diversity',
#   'worklife',
#   'personaldevelopment',
#   'growth',
#   'environment',
#   'leadership'],
#  ['culture', 'culture', 'growth', 'personaldevelopment', 'pay', 'pay'],
#  ['leadership', 'culture', 'personaldevelopment', 'culture', 'growth'],
#  ['culture', 'culture', 'environment', 'pay', 'pay', 'culture'],
#  [],
#  ['culture',
#   'leadership',
#   'personaldevelopment',
#   'culture',
#   'leadership',
#   'pay',
#   'pay'],
#  ['worklife', 'worklife', 'pay'],
#  ['culture', 'environment'],
#  ['culture', 'culture'],
#  ['worklife', 'worklife', 'personaldevelopment', 'pay', 'growth', 'culture'],
#  ['culture', 'personaldevelopment', 'personaldevelopment', 'growth'],
#  ['leadership', 'culture'],
#  ['culture',
#   'leadership',
#   'diversity',
#   'leadership',
#   'culture',
#   'diversity',
#   'pay',
#   'worklife',
#   'worklife',
#   'culture',
#   'culture',
#   'environment',
#   'culture',
#   'pay',
#   'growth'],
#  ['leadership',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'leadership',
#   'culture',
#   'culture'],
#  ['culture', 'personaldevelopment'],
#  ['culture', 'culture', 'culture', 'environment'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'environment',
#   'leadership',
#   'leadership',
#   'pay'],
#  ['culture',
#   'growth',
#   'leadership',
#   'growth',
#   'pay',
#   'culture',
#   'growth',
#   'culture'],
#  ['pay', 'worklife', 'culture'],
#  ['growth', 'growth', 'culture', 'pay', 'environment'],
#  ['culture', 'culture', 'pay', 'worklife', 'worklife', 'diversity'],
#  ['worklife',
#   'worklife',
#   'personaldevelopment',
#   'growth',
#   'personaldevelopment'],
#  ['pay', 'pay'],
#  ['culture', 'culture', 'pay', 'pay', 'pay'],
#  ['pay', 'pay'],
#  ['culture', 'worklife', 'worklife', 'culture', 'personaldevelopment', 'pay'],
#  ['culture', 'pay'],
#  ['culture', 'culture', 'growth', 'growth'],
#  ['environment', 'environment', 'pay'],
#  ['culture', 'culture', 'personaldevelopment'],
#  ['environment'],
#  [],
#  ['worklife', 'environment', 'diversity'],
#  ['culture', 'leadership'],
#  ['culture', 'culture', 'pay'],
#  ['culture'],
#  ['culture', 'pay', 'worklife', 'worklife', 'culture'],
#  ['culture'],
#  ['culture', 'culture', 'pay', 'personaldevelopment'],
#  ['culture', 'culture', 'culture', 'culture', 'environment'],
#  ['pay', 'culture'],
#  ['pay', 'culture'],
#  ['culture', 'culture'],
#  ['culture', 'pay', 'culture', 'leadership', 'leadership'],
#  ['worklife', 'worklife'],
#  ['leadership', 'culture'],
#  ['culture'],
#  ['culture', 'environment', 'pay'],
#  ['culture', 'culture', 'environment'],
#  ['pay'],
#  ['culture'],
#  ['pay', 'culture', 'culture', 'growth', 'growth'],
#  ['culture'],
#  ['culture', 'pay', 'pay'],
#  ['worklife', 'worklife', 'culture'],
#  ['culture'],
#  ['culture', 'culture'],
#  ['culture', 'environment', 'worklife', 'worklife'],
#  [],
#  ['pay', 'pay', 'personaldevelopment', 'environment', 'culture'],
#  ['culture', 'leadership', 'culture', 'growth', 'pay', 'pay', 'culture'],
#  ['pay', 'culture', 'pay', 'environment'],
#  ['culture', 'culture', 'leadership', 'pay', 'culture', 'culture'],
#  ['worklife', 'worklife', 'growth'],
#  ['culture', 'culture', 'growth'],
#  ['worklife', 'worklife', 'worklife', 'pay'],
#  ['environment'],
#  ['diversity',
#   'environment',
#   'culture',
#   'pay',
#   'culture',
#   'personaldevelopment',
#   'personaldevelopment',
#   'personaldevelopment'],
#  ['worklife', 'worklife', 'culture', 'culture', 'environment'],
#  ['culture', 'culture', 'environment', 'pay'],
#  ['culture'],
#  ['culture', 'growth'],
#  ['worklife', 'worklife'],
#  ['culture', 'leadership', 'culture'],
#  ['culture', 'worklife', 'worklife'],
#  ['environment',
#   'growth',
#   'culture',
#   'leadership',
#   'environment',
#   'culture',
#   'culture',
#   'culture'],
#  [],
#  ['culture', 'culture', 'worklife', 'worklife'],
#  ['worklife', 'worklife', 'pay', 'leadership'],
#  [],
#  ['culture', 'culture', 'growth', 'pay', 'pay', 'culture', 'leadership'],
#  ['pay', 'worklife', 'environment'],
#  ['culture', 'leadership', 'culture'],
#  ['pay'],
#  ['pay', 'pay', 'culture'],
#  ['diversity'],
#  ['culture', 'culture'],
#  ['culture', 'leadership', 'culture', 'growth', 'pay', 'pay'],
#  ['pay'],
#  ['culture', 'culture', 'worklife', 'culture', 'culture', 'pay'],
#  ['culture', 'culture', 'culture', 'pay', 'leadership', 'culture'],
#  [],
#  ['culture', 'worklife', 'worklife', 'pay'],
#  ['worklife', 'culture', 'personaldevelopment', 'culture', 'environment'],
#  ['culture', 'environment', 'pay', 'growth', 'culture'],
#  ['culture',
#   'growth',
#   'culture',
#   'pay',
#   'culture',
#   'worklife',
#   'worklife',
#   'worklife',
#   'culture'],
#  ['pay', 'culture'],
#  ['environment'],
#  ['culture',
#   'pay',
#   'culture',
#   'worklife',
#   'culture',
#   'leadership',
#   'leadership'],
#  ['pay', 'pay'],
#  ['culture', 'pay', 'culture'],
#  ['culture', 'environment'],
#  ['environment', 'culture', 'culture', 'environment'],
#  ['pay', 'worklife', 'worklife', 'culture'],
#  ['culture', 'culture'],
#  ['pay', 'pay', 'pay', 'culture'],
#  ['worklife',
#   'pay',
#   'leadership',
#   'culture',
#   'pay',
#   'pay',
#   'culture',
#   'diversity'],
#  ['leadership', 'culture'],
#  ['leadership', 'culture', 'culture', 'pay', 'pay', 'culture', 'culture'],
#  ['pay', 'culture', 'culture', 'culture'],
#  ['culture', 'culture', 'pay'],
#  ['pay', 'culture'],
#  ['leadership', 'environment'],
#  ['diversity'],
#  ['growth', 'growth', 'personaldevelopment', 'leadership'],
#  ['personaldevelopment'],
#  ['culture', 'culture'],
#  ['pay', 'pay'],
#  ['worklife', 'personaldevelopment'],
#  ['worklife', 'worklife'],
#  ['culture', 'worklife', 'culture', 'diversity'],
#  ['culture'],
#  ['growth', 'growth'],
#  ['worklife', 'worklife', 'environment', 'culture', 'culture'],
#  ['culture', 'culture'],
#  ['culture', 'culture', 'environment', 'culture'],
#  ['pay', 'worklife', 'worklife', 'culture'],
#  ['environment', 'worklife', 'worklife'],
#  ['worklife', 'environment', 'environment'],
#  [],
#  ['culture', 'culture', 'culture'],
#  ['pay', 'culture', 'worklife', 'worklife', 'culture'],
#  ['growth',
#   'leadership',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture'],
#  ['culture', 'culture'],
#  ['diversity',
#   'culture',
#   'culture',
#   'culture',
#   'environment',
#   'environment',
#   'personaldevelopment'],
#  ['leadership', 'worklife', 'worklife'],
#  ['diversity', 'culture'],
#  ['culture', 'worklife', 'worklife', 'growth', 'growth', 'culture', 'pay'],
#  ['environment', 'pay', 'worklife'],
#  ['pay', 'leadership', 'culture', 'pay'],
#  ['culture'],
#  ['culture'],
#  ['pay',
#   'environment',
#   'environment',
#   'worklife',
#   'worklife',
#   'worklife',
#   'worklife'],
#  ['pay', 'culture', 'pay'],
#  ['worklife',
#   'worklife',
#   'worklife',
#   'diversity',
#   'environment',
#   'leadership'],
#  [],
#  ['environment',
#   'culture',
#   'culture',
#   'culture',
#   'growth',
#   'personaldevelopment',
#   'growth'],
#  [],
#  ['growth', 'growth', 'growth'],
#  ['culture', 'culture'],
#  ['personaldevelopment', 'personaldevelopment', 'environment'],
#  ['culture', 'culture', 'worklife'],
#  ['environment', 'pay', 'culture', 'leadership'],
#  ['worklife',
#   'worklife',
#   'culture',
#   'leadership',
#   'culture',
#   'culture',
#   'culture',
#   'culture'],
#  ['growth',
#   'growth',
#   'personaldevelopment',
#   'worklife',
#   'worklife',
#   'environment'],
#  ['culture', 'environment', 'pay', 'culture', 'culture'],
#  ['personaldevelopment', 'personaldevelopment', 'culture'],
#  ['worklife', 'worklife', 'worklife'],
#  ['pay', 'culture', 'pay'],
#  ['growth'],
#  ['culture'],
#  ['culture', 'culture', 'culture'],
#  ['culture'],
#  ['pay', 'culture', 'pay'],
#  ['worklife'],
#  ['culture', 'personaldevelopment', 'culture', 'growth'],
#  ['culture', 'culture'],
#  ['culture',
#   'leadership',
#   'culture',
#   'culture',
#   'environment',
#   'culture',
#   'culture',
#   'worklife',
#   'pay'],
#  ['culture', 'diversity', 'culture', 'environment', 'worklife', 'worklife'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'pay',
#   'culture',
#   'worklife',
#   'worklife',
#   'worklife'],
#  ['diversity', 'growth', 'culture', 'leadership'],
#  ['pay', 'culture', 'personaldevelopment', 'culture', 'environment'],
#  ['personaldevelopment'],
#  ['culture', 'leadership', 'culture'],
#  ['culture', 'culture', 'environment'],
#  ['worklife', 'culture', 'environment', 'worklife', 'worklife'],
#  ['culture',
#   'leadership',
#   'culture',
#   'pay',
#   'pay',
#   'diversity',
#   'environment'],
#  ['pay'],
#  ['worklife', 'worklife', 'environment'],
#  [],
#  ['culture', 'culture', 'worklife', 'worklife'],
#  ['leadership'],
#  ['leadership', 'culture'],
#  ['pay', 'environment', 'pay', 'growth', 'culture'],
#  ['personaldevelopment', 'diversity', 'culture', 'pay', 'pay', 'pay'],
#  ['diversity', 'environment', 'worklife', 'worklife'],
#  ['culture', 'pay', 'worklife'],
#  ['environment', 'culture', 'culture'],
#  ['worklife', 'pay', 'pay', 'culture', 'culture', 'culture'],
#  ['culture', 'culture', 'culture', 'pay'],
#  ['worklife', 'worklife', 'culture'],
#  ['worklife', 'worklife'],
#  ['pay', 'culture', 'environment', 'worklife'],
#  ['pay', 'growth', 'culture', 'culture', 'culture'],
#  ['culture',
#   'pay',
#   'culture',
#   'leadership',
#   'culture',
#   'culture',
#   'culture',
#   'environment',
#   'culture'],
#  ['leadership', 'culture', 'worklife', 'worklife', 'leadership'],
#  ['environment', 'culture', 'leadership', 'personaldevelopment'],
#  ['worklife', 'leadership', 'leadership', 'culture', 'worklife', 'worklife'],
#  [],
#  ['culture', 'culture'],
#  ['pay', 'pay', 'leadership'],
#  ['diversity',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'environment',
#   'pay',
#   'pay'],
#  [],
#  ['environment'],
#  ['culture', 'worklife', 'worklife'],
#  ['culture', 'culture', 'pay', 'worklife', 'leadership'],
#  ['culture'],
#  ['culture', 'personaldevelopment'],
#  ['pay', 'worklife', 'environment'],
#  ['pay', 'pay', 'worklife'],
#  ['culture', 'pay', 'growth', 'culture'],
#  ['culture', 'culture', 'culture', 'growth'],
#  ['culture',
#   'leadership',
#   'culture',
#   'culture',
#   'worklife',
#   'worklife',
#   'pay'],
#  ['worklife', 'culture'],
#  ['culture',
#   'growth',
#   'culture',
#   'culture',
#   'worklife',
#   'worklife',
#   'pay',
#   'pay'],
#  ['leadership', 'culture', 'culture'],
#  ['leadership', 'culture'],
#  ['worklife', 'worklife', 'culture'],
#  ['culture',
#   'culture',
#   'culture',
#   'environment',
#   'leadership',
#   'culture',
#   'pay',
#   'pay'],
#  ['culture', 'pay', 'pay'],
#  ['personaldevelopment', 'personaldevelopment', 'culture', 'culture', 'pay'],
#  ['worklife', 'worklife', 'worklife'],
#  ['culture', 'worklife'],
#  ['environment', 'culture', 'worklife', 'worklife'],
#  [],
#  ['culture', 'culture'],
#  ['culture', 'culture', 'culture'],
#  [],
#  ['pay', 'personaldevelopment', 'personaldevelopment'],
#  ['culture', 'environment', 'diversity', 'leadership'],
#  ['personaldevelopment'],
#  ['growth', 'leadership', 'culture', 'personaldevelopment', 'growth'],
#  ['personaldevelopment',
#   'culture',
#   'growth',
#   'culture',
#   'worklife',
#   'environment',
#   'pay',
#   'worklife'],
#  ['culture'],
#  ['growth'],
#  ['culture', 'pay', 'pay'],
#  ['culture'],
#  ['environment', 'environment', 'diversity', 'worklife', 'worklife'],
#  ['culture'],
#  ['pay', 'culture'],
#  ['culture', 'culture', 'culture', 'growth'],
#  ['culture', 'environment', 'culture', 'personaldevelopment'],
#  ['culture', 'pay'],
#  ['growth'],
#  ['environment',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'personaldevelopment',
#   'personaldevelopment',
#   'growth',
#   'personaldevelopment',
#   'personaldevelopment'],
#  ['growth', 'culture', 'pay'],
#  ['culture', 'diversity'],
#  ['culture', 'pay', 'growth', 'culture'],
#  ['culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'diversity'],
#  ['personaldevelopment', 'personaldevelopment', 'culture'],
#  ['culture', 'personaldevelopment', 'culture'],
#  [],
#  ['environment'],
#  ['growth'],
#  ['culture',
#   'environment',
#   'worklife',
#   'worklife',
#   'culture',
#   'growth',
#   'growth'],
#  ['worklife',
#   'worklife',
#   'worklife',
#   'culture',
#   'personaldevelopment',
#   'personaldevelopment',
#   'personaldevelopment'],
#  ['culture',
#   'culture',
#   'growth',
#   'worklife',
#   'worklife',
#   'leadership',
#   'environment',
#   'culture'],
#  ['worklife', 'worklife', 'pay', 'leadership'],
#  ['culture', 'growth', 'diversity', 'culture', 'culture'],
#  ['environment', 'environment', 'growth', 'personaldevelopment'],
#  ...]

# %%
con_attributes = []


for row in range(len(reviews_df)):
    text=reviews_df['con_replace_token'].iloc[row]
    attributelist = list()
    for word in text:
        if word.is_punct:
            continue
        if word.text in featuresnames:
            attributelist.append(word.text)
    con_attributes.append(attributelist)
con_attributes
# Out:
# [[],
#  ['pay'],
#  [],
#  [],
#  [],
#  ['worklife'],
#  ['culture', 'culture', 'culture', 'personaldevelopment'],
#  ['pay', 'culture'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['pay', 'pay'],
#  [],
#  [],
#  ['culture'],
#  ['culture'],
#  [],
#  ['culture'],
#  [],
#  [],
#  [],
#  ['environment', 'culture'],
#  ['leadership', 'worklife'],
#  ['pay'],
#  ['leadership', 'personaldevelopment'],
#  [],
#  ['worklife', 'worklife'],
#  [],
#  ['culture'],
#  ['pay', 'pay'],
#  [],
#  [],
#  [],
#  ['pay', 'culture'],
#  ['pay'],
#  ['pay'],
#  ['leadership'],
#  ['worklife'],
#  [],
#  ['leadership'],
#  ['pay'],
#  ['leadership'],
#  ['growth', 'culture', 'culture', 'culture', 'culture'],
#  ['culture', 'culture', 'personaldevelopment'],
#  ['culture'],
#  ['pay', 'culture'],
#  [],
#  ['culture', 'worklife', 'worklife', 'pay'],
#  [],
#  ['leadership'],
#  ['worklife', 'pay'],
#  [],
#  ['culture'],
#  [],
#  ['worklife'],
#  ['culture'],
#  ['culture', 'culture', 'culture'],
#  ['pay'],
#  [],
#  [],
#  ['pay'],
#  ['pay'],
#  ['environment', 'growth'],
#  [],
#  [],
#  ['pay'],
#  ['pay'],
#  ['pay'],
#  [],
#  ['pay', 'culture'],
#  [],
#  [],
#  ['pay'],
#  [],
#  [],
#  ['culture'],
#  ['pay'],
#  [],
#  [],
#  [],
#  ['pay', 'pay'],
#  ['pay'],
#  [],
#  ['culture'],
#  [],
#  ['pay'],
#  ['worklife'],
#  ['pay', 'culture'],
#  ['worklife'],
#  [],
#  ['pay'],
#  [],
#  [],
#  [],
#  [],
#  ['pay', 'pay'],
#  [],
#  [],
#  ['leadership'],
#  ['culture', 'environment', 'culture'],
#  ['environment', 'environment'],
#  ['culture', 'personaldevelopment', 'personaldevelopment', 'culture'],
#  [],
#  [],
#  ['personaldevelopment'],
#  ['culture', 'leadership'],
#  ['worklife', 'worklife', 'environment', 'growth'],
#  ['culture', 'growth'],
#  ['pay'],
#  [],
#  [],
#  [],
#  ['culture'],
#  [],
#  ['pay', 'environment'],
#  [],
#  ['personaldevelopment', 'personaldevelopment', 'culture', 'culture'],
#  ['leadership', 'culture'],
#  [],
#  ['environment'],
#  [],
#  [],
#  [],
#  [],
#  ['culture'],
#  ['leadership'],
#  [],
#  [],
#  ['pay', 'culture', 'environment', 'personaldevelopment'],
#  ['leadership', 'personaldevelopment'],
#  [],
#  ['culture'],
#  ['culture'],
#  ['worklife', 'worklife'],
#  [],
#  ['leadership'],
#  ['leadership', 'diversity', 'culture'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['worklife'],
#  [],
#  ['culture', 'leadership'],
#  ['leadership'],
#  [],
#  [],
#  [],
#  [],
#  ['growth', 'leadership'],
#  [],
#  [],
#  [],
#  ['environment'],
#  [],
#  ['pay', 'pay', 'leadership'],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['growth', 'leadership'],
#  ['leadership', 'culture', 'pay'],
#  ['personaldevelopment'],
#  ['environment'],
#  [],
#  ['personaldevelopment', 'leadership', 'culture'],
#  [],
#  ['growth'],
#  ['culture'],
#  ['leadership'],
#  ['culture', 'growth'],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['pay'],
#  [],
#  ['culture'],
#  ['pay', 'leadership'],
#  ['leadership', 'growth'],
#  [],
#  ['culture'],
#  ['culture'],
#  [],
#  ['culture', 'growth'],
#  ['worklife'],
#  [],
#  ['culture'],
#  ['leadership', 'leadership'],
#  ['leadership'],
#  ['culture', 'leadership'],
#  ['culture'],
#  ['environment', 'culture'],
#  ['leadership', 'culture'],
#  ['leadership', 'leadership', 'culture'],
#  ['personaldevelopment'],
#  ['worklife', 'worklife'],
#  ['growth', 'worklife', 'worklife'],
#  ['growth', 'growth', 'worklife', 'personaldevelopment'],
#  ['culture',
#   'leadership',
#   'leadership',
#   'culture',
#   'culture',
#   'culture',
#   'culture'],
#  ['culture', 'growth'],
#  [],
#  ['leadership'],
#  [],
#  ['worklife'],
#  [],
#  [],
#  ['worklife', 'worklife'],
#  [],
#  ['worklife'],
#  [],
#  ['worklife', 'worklife'],
#  ['worklife'],
#  ['leadership', 'worklife'],
#  ['pay'],
#  [],
#  [],
#  ['worklife', 'worklife', 'culture', 'leadership'],
#  ['leadership'],
#  [],
#  ['leadership', 'culture'],
#  [],
#  [],
#  [],
#  [],
#  ['culture'],
#  ['pay'],
#  ['leadership'],
#  [],
#  ['culture', 'pay'],
#  ['environment'],
#  [],
#  [],
#  [],
#  [],
#  ['worklife'],
#  ['culture'],
#  ['worklife', 'worklife', 'leadership'],
#  ['pay'],
#  ['environment', 'pay'],
#  ['pay', 'pay', 'environment'],
#  ['pay'],
#  [],
#  ['worklife', 'environment'],
#  ['worklife'],
#  [],
#  [],
#  ['worklife'],
#  ['pay', 'culture'],
#  [],
#  ['environment'],
#  [],
#  ['worklife'],
#  [],
#  [],
#  [],
#  ['worklife'],
#  ['pay'],
#  [],
#  [],
#  ['pay'],
#  ['environment', 'worklife'],
#  ['worklife', 'worklife'],
#  ['growth'],
#  [],
#  ['pay', 'worklife'],
#  ['leadership'],
#  [],
#  [],
#  [],
#  ['worklife'],
#  [],
#  [],
#  ['worklife'],
#  [],
#  [],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['pay', 'culture', 'environment'],
#  [],
#  [],
#  ['pay', 'environment', 'pay'],
#  ['pay', 'pay', 'pay'],
#  [],
#  [],
#  ['growth'],
#  [],
#  ['leadership'],
#  ['worklife'],
#  ['worklife', 'leadership'],
#  [],
#  [],
#  ['personaldevelopment'],
#  ['culture', 'environment'],
#  ['culture'],
#  ['culture', 'pay', 'pay', 'pay', 'pay'],
#  [],
#  [],
#  ['culture'],
#  ['culture', 'diversity'],
#  ['pay'],
#  ['leadership'],
#  ['leadership'],
#  [],
#  ['leadership'],
#  [],
#  ['culture', 'leadership', 'growth', 'leadership'],
#  ['culture'],
#  ['personaldevelopment'],
#  ['pay', 'pay'],
#  ['leadership',
#   'personaldevelopment',
#   'leadership',
#   'culture',
#   'worklife',
#   'pay',
#   'pay'],
#  [],
#  ['culture'],
#  ['growth', 'culture', 'culture', 'personaldevelopment'],
#  [],
#  ['culture', 'worklife', 'pay'],
#  ['leadership',
#   'personaldevelopment',
#   'pay',
#   'pay',
#   'worklife',
#   'culture',
#   'leadership',
#   'culture'],
#  ['pay',
#   'pay',
#   'culture',
#   'culture',
#   'culture',
#   'leadership',
#   'culture',
#   'environment'],
#  [],
#  ['personaldevelopment'],
#  ['pay', 'pay', 'culture'],
#  [],
#  ['culture'],
#  ['leadership'],
#  ['pay'],
#  ['leadership', 'environment', 'growth'],
#  ['leadership', 'culture', 'leadership'],
#  ['pay', 'leadership', 'pay'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['leadership'],
#  ['leadership'],
#  ['worklife', 'growth', 'culture', 'environment', 'pay', 'pay'],
#  ['leadership', 'environment'],
#  [],
#  ['culture'],
#  ['leadership', 'environment'],
#  ['leadership'],
#  ['pay', 'culture'],
#  ['culture'],
#  ['leadership'],
#  ['leadership', 'personaldevelopment'],
#  ['culture'],
#  [],
#  [],
#  [],
#  ['pay'],
#  [],
#  ['culture', 'culture'],
#  ['pay', 'pay', 'culture'],
#  [],
#  ['culture', 'pay'],
#  ['pay'],
#  ['personaldevelopment', 'culture'],
#  ['culture'],
#  [],
#  ['culture'],
#  [],
#  [],
#  ['pay'],
#  ['leadership'],
#  ['worklife', 'worklife'],
#  [],
#  ['culture'],
#  ['environment'],
#  ['growth',
#   'pay',
#   'pay',
#   'culture',
#   'culture',
#   'leadership',
#   'worklife',
#   'worklife'],
#  ['growth', 'leadership'],
#  [],
#  [],
#  ['environment',
#   'environment',
#   'culture',
#   'environment',
#   'leadership',
#   'culture',
#   'culture',
#   'culture',
#   'culture'],
#  [],
#  [],
#  [],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['culture'],
#  ['culture'],
#  ['culture', 'culture'],
#  [],
#  ['culture', 'culture', 'diversity'],
#  ['leadership'],
#  ['worklife', 'growth'],
#  [],
#  ['culture', 'culture'],
#  ['pay', 'worklife', 'worklife', 'culture'],
#  ['worklife'],
#  [],
#  [],
#  [],
#  [],
#  ['personaldevelopment', 'culture'],
#  [],
#  ['culture', 'culture', 'worklife', 'worklife', 'worklife', 'leadership'],
#  ['worklife', 'worklife', 'pay', 'environment'],
#  ['worklife', 'worklife', 'personaldevelopment'],
#  ['culture'],
#  ['environment'],
#  [],
#  [],
#  ['pay'],
#  ['culture',
#   'culture',
#   'culture',
#   'culture',
#   'pay',
#   'leadership',
#   'leadership',
#   'leadership',
#   'culture',
#   'pay',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'environment'],
#  ['culture', 'worklife'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['worklife', 'worklife'],
#  ['worklife'],
#  [],
#  ['culture', 'culture', 'leadership', 'growth', 'leadership'],
#  [],
#  ['personaldevelopment', 'leadership'],
#  ['environment'],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['worklife'],
#  [],
#  [],
#  ['culture', 'culture'],
#  [],
#  [],
#  [],
#  ['leadership', 'culture', 'pay', 'pay', 'pay'],
#  ['worklife', 'worklife'],
#  [],
#  [],
#  [],
#  ['culture', 'worklife'],
#  ['culture', 'culture'],
#  ['worklife', 'pay'],
#  [],
#  [],
#  ['culture', 'personaldevelopment'],
#  ['worklife'],
#  [],
#  [],
#  [],
#  ['culture'],
#  [],
#  [],
#  ['pay'],
#  [],
#  [],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['culture', 'culture', 'environment', 'personaldevelopment', 'culture'],
#  ['culture'],
#  ['leadership'],
#  [],
#  ['culture'],
#  ['worklife'],
#  ['diversity'],
#  ['pay', 'environment'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['culture'],
#  ['culture'],
#  ['culture'],
#  [],
#  ['pay', 'worklife'],
#  [],
#  [],
#  [],
#  ['culture', 'growth'],
#  [],
#  [],
#  ['worklife', 'worklife'],
#  [],
#  [],
#  ['pay', 'culture'],
#  ['personaldevelopment'],
#  [],
#  [],
#  ['culture', 'culture', 'personaldevelopment'],
#  ['growth'],
#  ['leadership'],
#  [],
#  ['culture'],
#  ['leadership', 'personaldevelopment'],
#  [],
#  [],
#  [],
#  ['growth', 'growth'],
#  ['environment'],
#  [],
#  [],
#  [],
#  [],
#  ['pay', 'growth'],
#  ['growth'],
#  [],
#  [],
#  ['culture'],
#  [],
#  [],
#  ['leadership', 'personaldevelopment', 'environment'],
#  ['leadership', 'culture', 'culture', 'environment'],
#  ['leadership'],
#  [],
#  [],
#  ['culture', 'leadership'],
#  ['worklife'],
#  ['personaldevelopment'],
#  [],
#  ['culture', 'environment'],
#  [],
#  ['culture'],
#  ['pay', 'personaldevelopment'],
#  [],
#  [],
#  [],
#  [],
#  ['personaldevelopment'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['worklife', 'personaldevelopment', 'culture', 'culture', 'leadership'],
#  ['environment'],
#  [],
#  [],
#  ['pay', 'culture'],
#  [],
#  [],
#  [],
#  ['leadership'],
#  ['growth', 'growth'],
#  ['pay', 'pay'],
#  ['culture', 'culture', 'leadership', 'pay'],
#  ['personaldevelopment'],
#  [],
#  [],
#  [],
#  [],
#  ['culture', 'culture'],
#  ['growth'],
#  ['leadership'],
#  [],
#  [],
#  [],
#  [],
#  ['culture', 'pay'],
#  ['culture', 'personaldevelopment'],
#  [],
#  [],
#  ['growth'],
#  ['culture'],
#  ['pay'],
#  [],
#  ['culture', 'leadership', 'culture', 'culture'],
#  [],
#  ['culture', 'personaldevelopment'],
#  ['pay'],
#  ['pay'],
#  ['leadership', 'pay', 'environment'],
#  [],
#  [],
#  [],
#  ['culture'],
#  [],
#  ['culture'],
#  [],
#  ['culture', 'culture', 'culture'],
#  ['culture', 'personaldevelopment', 'environment'],
#  [],
#  ['leadership', 'culture', 'culture', 'leadership', 'culture'],
#  ['pay'],
#  ['pay', 'culture'],
#  [],
#  [],
#  [],
#  ['worklife',
#   'worklife',
#   'worklife',
#   'environment',
#   'pay',
#   'leadership',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'leadership',
#   'culture',
#   'culture',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'leadership',
#   'growth',
#   'leadership',
#   'leadership',
#   'leadership',
#   'culture',
#   'culture',
#   'leadership',
#   'culture'],
#  ['growth', 'culture', 'growth', 'culture', 'culture', 'culture'],
#  [],
#  ['culture', 'growth'],
#  ['worklife'],
#  [],
#  [],
#  [],
#  [],
#  ['personaldevelopment', 'personaldevelopment', 'leadership'],
#  [],
#  ['culture', 'culture'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['culture'],
#  [],
#  ['worklife'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['worklife'],
#  ['leadership'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['culture'],
#  [],
#  [],
#  ['culture'],
#  ['growth'],
#  ['culture'],
#  ['worklife'],
#  [],
#  [],
#  [],
#  ['worklife'],
#  [],
#  ['culture'],
#  [],
#  ['worklife'],
#  ['culture', 'culture'],
#  ['culture'],
#  [],
#  ['culture', 'culture', 'culture'],
#  [],
#  ['culture', 'culture'],
#  [],
#  ['culture'],
#  ['culture'],
#  ['growth'],
#  [],
#  [],
#  ['growth'],
#  [],
#  ['leadership'],
#  ['culture'],
#  [],
#  [],
#  [],
#  [],
#  ['culture'],
#  [],
#  ['personaldevelopment'],
#  ['culture'],
#  [],
#  [],
#  ['culture'],
#  [],
#  [],
#  [],
#  [],
#  ['worklife'],
#  [],
#  [],
#  ['leadership', 'leadership', 'culture', 'leadership', 'leadership'],
#  ['culture'],
#  ['growth'],
#  ['personaldevelopment', 'leadership', 'culture'],
#  ['culture'],
#  [],
#  [],
#  ['worklife'],
#  [],
#  ['growth', 'growth'],
#  ['personaldevelopment', 'personaldevelopment', 'worklife'],
#  ['worklife',
#   'worklife',
#   'personaldevelopment',
#   'culture',
#   'personaldevelopment',
#   'growth',
#   'growth'],
#  [],
#  ['growth'],
#  ['culture'],
#  ['culture', 'culture'],
#  ['culture'],
#  ['pay', 'environment', 'personaldevelopment'],
#  ['culture', 'growth'],
#  ['pay',
#   'pay',
#   'pay',
#   'worklife',
#   'leadership',
#   'growth',
#   'leadership',
#   'culture',
#   'personaldevelopment'],
#  [],
#  [],
#  ['growth', 'leadership', 'growth'],
#  ['culture', 'culture', 'culture', 'culture', 'culture'],
#  ['culture'],
#  ['culture'],
#  ['personaldevelopment'],
#  [],
#  ['culture'],
#  ['pay'],
#  ['environment'],
#  ['worklife', 'worklife', 'personaldevelopment'],
#  ['environment', 'worklife'],
#  [],
#  ['culture', 'culture'],
#  [],
#  [],
#  ['culture'],
#  [],
#  [],
#  ['culture', 'culture'],
#  ['pay', 'environment'],
#  ['culture'],
#  [],
#  ['leadership'],
#  [],
#  ['growth', 'growth', 'leadership', 'culture'],
#  ['leadership'],
#  ['worklife'],
#  ['culture'],
#  [],
#  ['culture', 'leadership', 'culture'],
#  ['culture'],
#  ['personaldevelopment'],
#  ['culture', 'culture', 'culture'],
#  ['culture'],
#  [],
#  ['culture', 'worklife', 'personaldevelopment'],
#  [],
#  [],
#  ['growth', 'growth'],
#  [],
#  ['culture', 'culture', 'culture'],
#  ['environment'],
#  ['personaldevelopment',
#   'culture',
#   'worklife',
#   'worklife',
#   'pay',
#   'pay',
#   'growth',
#   'growth'],
#  ['culture', 'leadership', 'personaldevelopment'],
#  [],
#  ['pay'],
#  [],
#  ['leadership', 'culture', 'culture'],
#  [],
#  ['culture', 'leadership', 'culture', 'growth'],
#  ['personaldevelopment'],
#  ['worklife'],
#  [],
#  ['pay', 'pay'],
#  [],
#  [],
#  ['culture'],
#  ['culture'],
#  ['culture'],
#  ['culture', 'growth'],
#  [],
#  [],
#  ['worklife',
#   'worklife',
#   'culture',
#   'culture',
#   'environment',
#   'growth',
#   'growth'],
#  [],
#  ['growth', 'pay'],
#  ['worklife'],
#  ['culture'],
#  ['personaldevelopment'],
#  [],
#  ['leadership', 'culture'],
#  ['environment'],
#  ['leadership', 'leadership', 'leadership'],
#  [],
#  ['culture'],
#  ['pay', 'culture'],
#  [],
#  [],
#  ['leadership'],
#  ['culture', 'growth'],
#  ['personaldevelopment'],
#  [],
#  [],
#  [],
#  ['growth'],
#  ['growth', 'growth'],
#  [],
#  ['leadership'],
#  ['environment'],
#  [],
#  ['culture'],
#  ['culture'],
#  [],
#  ['culture'],
#  ['culture'],
#  ['leadership', 'environment'],
#  [],
#  [],
#  [],
#  ['environment', 'environment'],
#  [],
#  [],
#  ['pay'],
#  [],
#  ['culture'],
#  ['growth', 'culture'],
#  [],
#  ['pay', 'leadership', 'culture', 'leadership', 'culture', 'culture'],
#  [],
#  ['environment'],
#  ['worklife', 'worklife'],
#  ['culture', 'culture', 'personaldevelopment'],
#  [],
#  ['worklife'],
#  ['personaldevelopment',
#   'personaldevelopment',
#   'pay',
#   'leadership',
#   'culture',
#   'growth',
#   'culture',
#   'diversity',
#   'culture',
#   'pay',
#   'leadership',
#   'personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'culture'],
#  ['culture', 'leadership'],
#  [],
#  ['personaldevelopment'],
#  ['leadership', 'leadership'],
#  ['diversity'],
#  [],
#  [],
#  [],
#  ['culture', 'environment'],
#  ['personaldevelopment', 'personaldevelopment'],
#  ['culture'],
#  ['growth', 'personaldevelopment', 'leadership'],
#  ['leadership',
#   'culture',
#   'worklife',
#   'culture',
#   'leadership',
#   'culture',
#   'personaldevelopment'],
#  [],
#  ['culture', 'leadership'],
#  [],
#  ['leadership', 'leadership', 'leadership', 'environment', 'culture'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['personaldevelopment', 'culture'],
#  [],
#  [],
#  ['culture'],
#  [],
#  ['worklife'],
#  ['culture', 'culture', 'culture'],
#  [],
#  ['pay'],
#  ['pay'],
#  ['leadership',
#   'leadership',
#   'leadership',
#   'personaldevelopment',
#   'leadership',
#   'culture',
#   'leadership',
#   'culture',
#   'culture'],
#  [],
#  ['leadership'],
#  ['culture'],
#  [],
#  ['environment'],
#  ['personaldevelopment'],
#  [],
#  ['culture', 'culture', 'culture', 'growth'],
#  [],
#  [],
#  ['worklife', 'environment', 'growth'],
#  ['pay'],
#  [],
#  [],
#  ['personaldevelopment'],
#  [],
#  ['culture'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['leadership', 'culture', 'culture', 'personaldevelopment', 'environment'],
#  ['culture', 'growth', 'personaldevelopment', 'environment'],
#  [],
#  [],
#  ['environment', 'culture', 'environment', 'environment'],
#  [],
#  [],
#  ['environment'],
#  ['personaldevelopment', 'growth'],
#  [],
#  ['leadership', 'pay', 'growth', 'personaldevelopment', 'personaldevelopment'],
#  [],
#  ['culture', 'personaldevelopment', 'culture'],
#  ['pay', 'worklife', 'worklife'],
#  ['growth'],
#  ['growth', 'pay', 'pay'],
#  ['pay'],
#  ['culture', 'culture', 'culture', 'leadership', 'culture'],
#  ['leadership'],
#  ['personaldevelopment',
#   'personaldevelopment',
#   'culture',
#   'growth',
#   'pay',
#   'growth',
#   'environment',
#   'environment',
#   'environment',
#   'environment',
#   'pay',
#   'personaldevelopment',
#   'leadership',
#   'culture',
#   'leadership',
#   'pay',
#   'culture',
#   'leadership',
#   'culture',
#   'culture',
#   'culture',
#   'leadership',
#   'leadership',
#   'culture',
#   'leadership',
#   'growth',
#   'growth',
#   'culture',
#   'leadership',
#   'culture',
#   'environment',
#   'environment',
#   'pay',
#   'diversity',
#   'diversity',
#   'diversity'],
#  [],
#  ['culture'],
#  ['pay', 'culture'],
#  ['environment'],
#  ['pay', 'environment'],
#  ['culture', 'culture'],
#  ['growth'],
#  ['pay', 'worklife', 'pay'],
#  [],
#  ['personaldevelopment', 'leadership'],
#  ['culture'],
#  ['culture'],
#  ['culture'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['environment', 'environment'],
#  ['culture',
#   'culture',
#   'diversity',
#   'leadership',
#   'culture',
#   'worklife',
#   'worklife'],
#  ['pay', 'culture'],
#  [],
#  [],
#  [],
#  [],
#  ['pay'],
#  ['culture',
#   'leadership',
#   'personaldevelopment',
#   'culture',
#   'culture',
#   'growth',
#   'growth',
#   'leadership',
#   'environment'],
#  ['pay', 'environment', 'culture'],
#  ['culture'],
#  ['pay'],
#  ['growth', 'personaldevelopment'],
#  [],
#  ['pay'],
#  ['pay'],
#  [],
#  ['pay'],
#  ['worklife'],
#  [],
#  [],
#  ['culture'],
#  [],
#  ['leadership', 'leadership', 'personaldevelopment'],
#  ['personaldevelopment', 'personaldevelopment'],
#  [],
#  ['pay', 'pay'],
#  ['growth'],
#  ['environment', 'culture'],
#  [],
#  ['culture', 'growth'],
#  ['growth', 'environment', 'culture'],
#  ['leadership', 'culture', 'environment', 'culture', 'culture'],
#  [],
#  [],
#  ['pay'],
#  [],
#  ['growth', 'culture'],
#  ['worklife', 'culture'],
#  [],
#  ['growth', 'culture'],
#  ['leadership'],
#  [],
#  ['culture'],
#  ['culture'],
#  [],
#  [],
#  [],
#  ['culture'],
#  [],
#  ['personaldevelopment', 'culture'],
#  [],
#  ['culture'],
#  ['personaldevelopment'],
#  ['worklife', 'worklife'],
#  [],
#  [],
#  [],
#  [],
#  ['leadership'],
#  ['environment'],
#  ['leadership'],
#  [],
#  ['growth'],
#  ['environment', 'culture'],
#  [],
#  ['culture',
#   'culture',
#   'culture',
#   'leadership',
#   'leadership',
#   'culture',
#   'culture',
#   'culture',
#   'culture',
#   'leadership',
#   'leadership',
#   'culture'],
#  ['culture', 'growth'],
#  ['personaldevelopment', 'culture'],
#  ['pay'],
#  [],
#  ['culture', 'growth', 'growth'],
#  [],
#  ['leadership', 'culture', 'culture', 'personaldevelopment', 'culture'],
#  ['growth'],
#  [],
#  ['growth', 'personaldevelopment', 'personaldevelopment'],
#  ['personaldevelopment'],
#  [],
#  ['growth', 'culture', 'culture'],
#  ...]

# %%
reviews_df['pro_attributes'] = pro_attributes
reviews_df['con_attributes'] = con_attributes
features = reviews_df[reviews_df['pro_attributes'].map(lambda d:len(d))>0]
features = reviews_df[reviews_df['con_attributes'].map(lambda d:len(d))>0]
features
# Out:
#       Unnamed: 0       company  \
# 1              1          Uber
# 5              5          Uber
# 6              6          Uber
# 7              7          Uber
# 18            18          Uber
# ...          ...           ...
# 9660        5891  VMware, Inc.
# 9661        5892  VMware, Inc.
# 9663        5894  VMware, Inc.
# 9664        5895  VMware, Inc.
# 9665        5896  VMware, Inc.
#
#                                                    pros  \
# 1                           Work your very own schedule
# 5     You can make a sizable pay with Uber, that's i...
# 6     I love working at Uber (corporate)! I think so...
# 7                            Money and time and fun and
# 18                          Good wlb and growth cilture
# ...                                                 ...
# 9660  Very focused on individual growth. Sustainable...
# 9661  wfh options, mentorship options, competitive p...
# 9663  Was a great place to make good money and be pa...
# 9664      work life balance, good to work with managers
# 9665  The culture and values of this company makes i...
#
#                                                    cons  \
# 1                   Sometimes the pay can be unbalanced
# 5     Driving can be stressful, so I would recommend...
# 6     Looks like we're going to head into hybrid wor...
# 7                           Pay and people and time and
# 18                        Pay bad stock kept going down
# ...                                                 ...
# 9660  You have to really want and enjoy the job of p...
# 9661            There is constantly changing leadership
# 9663  Dell has had too heavy of an influence on the ...
# 9664              easy to get some fantastic experience
# 9665  No cons to share best company to become a part...
#
#                                               con_token  \
# 1            (Sometimes, the, pay, can, be, unbalanced)
# 5     (Driving, can, be, stressful, ,, so, I, would,...
# 6     (Looks, like, we, 're, going, to, head, into, ...
# 7                    (Pay, and, people, and, time, and)
# 18                 (Pay, bad, stock, kept, going, down)
# ...                                                 ...
# 9660  (You, have, to, really, want, and, enjoy, the,...
# 9661      (There, is, constantly, changing, leadership)
# 9663  (Dell, has, had, too, heavy, of, an, influence...
# 9664       (easy, to, get, some, fantastic, experience)
# 9665  (No, cons, to, share, best, company, to, becom...
#
#                                               pro_token  \
# 1                     (Work, your, very, own, schedule)
# 5     (You, can, make, a, sizable, pay, with, Uber, ...
# 6     (I, love, working, at, Uber, (, corporate, ), ...
# 7                     (Money, and, time, and, fun, and)
# 18                    (Good, wlb, and, growth, cilture)
# ...                                                 ...
# 9660  (Very, focused, on, individual, growth, ., Sus...
# 9661  (wfh, options, ,, mentorship, options, ,, comp...
# 9663  (Was, a, great, place, to, make, good, money, ...
# 9664  (work, life, balance, ,, good, to, work, with,...
# 9665  (The, culture, and, values, of, this, company,...
#
#                                             pro_replace  \
# 1                                         work worklife
# 5                         sizable pay uber willing work
# 6     love working uber corporate think culture nerv...
# 7                                      pay time culture
# 18                              good wlb growth cilture
# ...                                                 ...
# 9660  focused individual growth sustainable pace liv...
# 9661      wfh pay mentorship pay culture pay health pay
# 9663  great place good pay growth brand great leader...
# 9664        work worklife worklife good work leadership
# 9665  culture culture culture makes great place work...
#
#                                             con_replace  \
# 1                                        pay unbalanced
# 5     driving stressful recommend divide driving tim...
# 6     looks like going head hybrid work 50 think cul...
# 7                                      pay culture time
# 18                               pay bad pay kept going
# ...                                                 ...
# 9660  want enjoy job professional services mgmt spen...
# 9661                     constantly changing leadership
# 9663  dell heavy influence culture vmware goes start...
# 9664                 easy fantastic personaldevelopment
# 9665  cons share best culture highly recommend vmwar...
#
#                                       con_replace_token  \
# 1                                     (pay, unbalanced)
# 5     (driving, stressful, recommend, divide, drivin...
# 6     (looks, like, going, head, hybrid, work, 50, t...
# 7                                  (pay, culture, time)
# 18                         (pay, bad, pay, kept, going)
# ...                                                 ...
# 9660  (want, enjoy, job, professional, services, mgm...
# 9661                 (constantly, changing, leadership)
# 9663  (dell, heavy, influence, culture, vmware, goes...
# 9664             (easy, fantastic, personaldevelopment)
# 9665  (cons, share, best, culture, highly, recommend...
#
#                                       pro_replace_token  \
# 1                                      (work, worklife)
# 5                   (sizable, pay, uber, willing, work)
# 6     (love, working, uber, corporate, think, cultur...
# 7                                  (pay, time, culture)
# 18                         (good, wlb, growth, cilture)
# ...                                                 ...
# 9660  (focused, individual, growth, sustainable, pac...
# 9661  (wfh, pay, mentorship, pay, culture, pay, heal...
# 9663  (great, place, good, pay, growth, brand, great...
# 9664  (work, worklife, worklife, good, work, leaders...
# 9665  (culture, culture, culture, makes, great, plac...
#
#                                              attributes  \
# 1                                            [worklife]
# 5                                                 [pay]
# 6     [culture, growth, growth, culture, culture, pe...
# 7                                        [pay, culture]
# 18                                             [growth]
# ...                                                 ...
# 9660  [growth, personaldevelopment, culture, leaders...
# 9661                      [pay, pay, culture, pay, pay]
# 9663                          [pay, growth, leadership]
# 9664                   [worklife, worklife, leadership]
# 9665      [culture, culture, culture, culture, culture]
#
#                                          pro_attributes  \
# 1                                            [worklife]
# 5                                                 [pay]
# 6     [culture, growth, growth, culture, culture, pe...
# 7                                        [pay, culture]
# 18                                             [growth]
# ...                                                 ...
# 9660  [growth, personaldevelopment, culture, leaders...
# 9661                      [pay, pay, culture, pay, pay]
# 9663                          [pay, growth, leadership]
# 9664                   [worklife, worklife, leadership]
# 9665      [culture, culture, culture, culture, culture]
#
#                                         con_attributes
# 1                                                [pay]
# 5                                           [worklife]
# 6     [culture, culture, culture, personaldevelopment]
# 7                                       [pay, culture]
# 18                                          [pay, pay]
# ...                                                ...
# 9660                             [personaldevelopment]
# 9661                                      [leadership]
# 9663                                         [culture]
# 9664                             [personaldevelopment]
# 9665                                [culture, culture]
#
# [5557 rows x 13 columns]

# %%
def count_firm_atb_pair(opinion,firm, attribute):
    count = 0
    for i in range(len(features)):
        if ((firm == features['company'].iloc[i]) and (attribute in features[opinion].iloc[i])):
            count += 1
    return count

# %%
def count_firm(firm):
    count = 0
    for i in range(len(reviews_df)):
        if (firm == reviews_df['company'].iloc[i]):
            count += 1
    return count

# %%
def count_attribute(opinion,attribute):
    count = 0
    for i in range(len(features)):
        if (attribute in features[opinion].iloc[i]):
            count += 1
    return count

# %%
def get_lift_atb (opinion, firm, attribute):
    numerator = len(reviews_df) * count_firm_atb_pair(opinion,firm, attribute)
    denominator = count_firm(firm) * count_attribute(opinion,attribute)
    return numerator / denominator

# %%
pro_list = []
for i in range(len(firmname)):
    firm_a = firmname[i]
    i_list = []
    for j in range(len(featuresnames)):
        attribute = featuresnames[j]
        lift = get_lift_atb('pro_attributes',firm_a, attribute)
        i_list.append(lift)
    pro_list.append(i_list)

# %%
con_list = []
for i in range(len(firmname)):
    firm_a = firmname[i]
    i_list = []
    for j in range(len(featuresnames)):
        attribute = featuresnames[j]
        lift = get_lift_atb('con_attributes',firm_a, attribute)
        i_list.append(lift)
    con_list.append(i_list)

# %%
pro_lift = pd.DataFrame(pro_list)
pro_lift.index = firmname
pro_lift.columns = featuresnames
pro_lift
# Out:
#                                                diversity  environment  \
# Booz Allen Hamilton Inc.                        0.000000     0.540112
# AirBnb, Inc.                                    0.878909     1.530317
# The Broad Institute                             1.757818     1.710354
# National Aeronautics and Space Administration   0.439455     0.900186
# Zynga                                           0.439455     1.890391
# ...                                                  ...          ...
# Ford Motor Company                              0.878909     0.180037
# General Electric Company                        0.000000     1.800372
# Doma Holdings, Inc.                             1.126807     0.692451
# Verizon Communications Inc.                     0.000000     0.900186
# PayPal, Inc.                                    2.929697     0.600124
#
#                                                 culture  worklife       pay  \
# Booz Allen Hamilton Inc.                       1.000532  1.313024  0.957727
# AirBnb, Inc.                                   1.029119  0.898385  0.856913
# The Broad Institute                            1.257812  0.552852  1.159353
# National Aeronautics and Space Administration  0.543146  0.691065  0.352847
# Zynga                                          1.086292  0.552852  1.411387
# ...                                                 ...       ...       ...
# Ford Motor Company                             0.628906  0.829278  0.907320
# General Electric Company                       0.929066  0.345533  0.756100
# Doma Holdings, Inc.                            0.952888  0.708785  0.775487
# Verizon Communications Inc.                    0.667021  1.382130  2.184289
# PayPal, Inc.                                   0.762310  1.151775  1.512200
#
#                                                  growth  leadership  \
# Booz Allen Hamilton Inc.                       0.678116    0.968953
# AirBnb, Inc.                                   0.290621    0.861292
# The Broad Institute                            1.549980    0.861292
# National Aeronautics and Space Administration  0.290621    0.215323
# Zynga                                          0.968737    0.215323
# ...                                                 ...         ...
# Ford Motor Company                             0.387495    0.000000
# General Electric Company                       0.484369    0.807461
# Doma Holdings, Inc.                            1.490365    1.656330
# Verizon Communications Inc.                    0.645825    1.076615
# PayPal, Inc.                                   0.322912    1.076615
#
#                                                personaldevelopment
# Booz Allen Hamilton Inc.                                  1.743553
# AirBnb, Inc.                                              0.610243
# The Broad Institute                                       1.569197
# National Aeronautics and Space Administration             0.958954
# Zynga                                                     0.871776
# ...                                                            ...
# Ford Motor Company                                        0.523066
# General Electric Company                                  1.307665
# Doma Holdings, Inc.                                       1.117662
# Verizon Communications Inc.                               1.452961
# PayPal, Inc.                                              0.581184
#
# [105 rows x 8 columns]

# %%
pro_lift.sort_values(by='diversity',ascending= False)
# Out:
#                                                     diversity  environment  \
# Affirm, Inc.                                         4.394545     1.980410
# Unity Technologies                                   3.515636     1.170242
# Intel Corporation                                    3.417980     0.400083
# Johns Hopkins University Applied Physics Labora...   3.076182     1.350279
# Intuit Inc.                                          2.929697     1.600331
# ...                                                       ...          ...
# Fidelity Management and Research LLC                 0.000000     0.450093
# Cloud BigData Technologies Group                     0.000000     0.090019
# Patagonia, Inc.                                      0.000000     1.080223
# Southwest Airlines Co.                               0.000000     0.720149
# Booz Allen Hamilton Inc.                             0.000000     0.540112
#
#                                                      culture  worklife  \
# Affirm, Inc.                                        1.515092  0.829278
# Unity Technologies                                  1.429332  0.967491
# Intel Corporation                                   0.730547  0.998205
# Johns Hopkins University Applied Physics Labora...  0.829012  1.727663
# Intuit Inc.                                         1.683435  0.614280
# ...                                                      ...       ...
# Fidelity Management and Research LLC                0.914772  0.898385
# Cloud BigData Technologies Group                    0.457386  0.207320
# Patagonia, Inc.                                     1.086292  0.552852
# Southwest Airlines Co.                              0.943359  1.243917
# Booz Allen Hamilton Inc.                            1.000532  1.313024
#
#                                                          pay    growth  \
# Affirm, Inc.                                        1.814640  1.840601
# Unity Technologies                                  1.260167  2.034349
# Intel Corporation                                   1.120148  1.184012
# Johns Hopkins University Applied Physics Labora...  1.562607  1.937475
# Intuit Inc.                                         1.120148  3.121487
# ...                                                      ...       ...
# Fidelity Management and Research LLC                1.209760  1.065611
# Cloud BigData Technologies Group                    0.252033  0.193747
# Patagonia, Inc.                                     1.008133  0.000000
# Southwest Airlines Co.                              1.915454  0.871864
# Booz Allen Hamilton Inc.                            0.957727  0.678116
#
#                                                     leadership  \
# Affirm, Inc.                                          1.507261
# Unity Technologies                                    2.153229
# Intel Corporation                                     0.956991
# Johns Hopkins University Applied Physics Labora...    0.322984
# Intuit Inc.                                           2.751349
# ...                                                        ...
# Fidelity Management and Research LLC                  0.861292
# Cloud BigData Technologies Group                      0.322984
# Patagonia, Inc.                                       0.322984
# Southwest Airlines Co.                                0.322984
# Booz Allen Hamilton Inc.                              0.968953
#
#                                                     personaldevelopment
# Affirm, Inc.                                                   1.830730
# Unity Technologies                                             1.220487
# Intel Corporation                                              1.065504
# Johns Hopkins University Applied Physics Labora...             1.394842
# Intuit Inc.                                                    2.227873
# ...                                                                 ...
# Fidelity Management and Research LLC                           0.610243
# Cloud BigData Technologies Group                               0.523066
# Patagonia, Inc.                                                0.435888
# Southwest Airlines Co.                                         0.348711
# Booz Allen Hamilton Inc.                                       1.743553
#
# [105 rows x 8 columns]

# %%
con_lift = pd.DataFrame(con_list)
con_lift.index = firmname
con_lift.columns = featuresnames
con_lift
# Out:
#                                                diversity  environment  \
# Booz Allen Hamilton Inc.                         0.84807     1.139087
# AirBnb, Inc.                                     1.69614     1.139087
# The Broad Institute                              0.84807     1.423859
# National Aeronautics and Space Administration    0.00000     1.993402
# Zynga                                            1.69614     1.139087
# ...                                                  ...          ...
# Ford Motor Company                               0.00000     1.139087
# General Electric Company                         0.00000     0.711929
# Doma Holdings, Inc.                              0.00000     0.730184
# Verizon Communications Inc.                      0.00000     0.474620
# PayPal, Inc.                                     0.00000     3.322337
#
#                                                 culture  worklife       pay  \
# Booz Allen Hamilton Inc.                       0.980925  0.645969  1.417029
# AirBnb, Inc.                                   1.137873  0.322984  0.322052
# The Broad Institute                            1.020162  0.968953  1.932312
# National Aeronautics and Space Administration  0.392370  0.430646  0.901746
# Zynga                                          1.608718  0.645969  0.322052
# ...                                                 ...       ...       ...
# Ford Motor Company                             0.941688  1.291938  0.515283
# General Electric Company                       0.980925  1.884076  1.127182
# Doma Holdings, Inc.                            0.804862  0.000000  0.330310
# Verizon Communications Inc.                    1.307900  1.435486  1.073507
# PayPal, Inc.                                   1.177110  0.717743  1.073507
#
#                                                  growth  leadership  \
# Booz Allen Hamilton Inc.                       0.878909    0.641859
# AirBnb, Inc.                                   0.781253    1.123253
# The Broad Institute                            1.953131    0.802324
# National Aeronautics and Space Administration  0.585939    0.401162
# Zynga                                          0.488283    1.845344
# ...                                                 ...         ...
# Ford Motor Company                             0.585939    0.641859
# General Electric Company                       0.976566    1.002905
# Doma Holdings, Inc.                            1.252007    0.411448
# Verizon Communications Inc.                    0.976566    2.139530
# PayPal, Inc.                                   1.627609    1.069765
#
#                                                personaldevelopment
# Booz Allen Hamilton Inc.                                  1.289067
# AirBnb, Inc.                                              1.189908
# The Broad Institute                                       2.181497
# National Aeronautics and Space Administration             1.289067
# Zynga                                                     1.090749
# ...                                                            ...
# Ford Motor Company                                        0.396636
# General Electric Company                                  0.495795
# Doma Holdings, Inc.                                       1.271269
# Verizon Communications Inc.                               0.661060
# PayPal, Inc.                                              0.991590
#
# [105 rows x 8 columns]

# %%
con_lift.sort_values(by='diversity',ascending= False)
# Out:
#                                diversity  environment   culture  worklife  \
# Healthcare Catalyst             5.088421     1.423859  1.922614  1.184276
# Paylocity Corporation           5.088421     0.854315  1.491006  2.045568
# American Express Company        4.711501     1.582065  0.915530  0.956991
# Fractal Analytics Inc           4.240351     1.067894  1.275203  1.211192
# Equinix, Inc.                   4.240351     0.996701  1.177110  0.430646
# ...                                  ...          ...       ...       ...
# The MathWorks, Inc.             0.000000     1.708630  1.137873  0.430646
# National Institutes of Health   0.000000     0.569543  0.549318  0.322984
# Intuit Inc.                     0.000000     0.791033  1.525884  1.315862
# Etsy, Inc.                      0.000000     1.708630  1.883377  1.291938
# PayPal, Inc.                    0.000000     3.322337  1.177110  0.717743
#
#                                     pay    growth  leadership  \
# Healthcare Catalyst            1.610260  1.464848    2.005809
# Paylocity Corporation          1.352618  1.660162    1.925577
# American Express Company       1.574476  0.651044    0.980618
# Fractal Analytics Inc          1.288208  1.586919    2.206390
# Equinix, Inc.                  0.450873  1.074222    1.925577
# ...                                 ...       ...         ...
# The MathWorks, Inc.            1.932312  1.367192    0.641859
# National Institutes of Health  0.966156  0.683596    0.401162
# Intuit Inc.                    0.500970  1.302088    0.980618
# Etsy, Inc.                     1.030566  1.269535    2.246506
# PayPal, Inc.                   1.073507  1.627609    1.069765
#
#                                personaldevelopment
# Healthcare Catalyst                       2.379815
# Paylocity Corporation                     2.379815
# American Express Company                  0.661060
# Fractal Analytics Inc                     1.983179
# Equinix, Inc.                             0.793272
# ...                                            ...
# The MathWorks, Inc.                       1.189908
# National Institutes of Health             0.694113
# Intuit Inc.                               1.322120
# Etsy, Inc.                                1.388226
# PayPal, Inc.                              0.991590
#
# [105 rows x 8 columns]

# %%
firmname == 'SouthernCompany'
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])
